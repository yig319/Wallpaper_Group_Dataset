# %%
# %load_ext autoreload
# %autoreload 2
import sys
import numpy as np
sys.path.append('../src/')
from symmetry_generator import symmetry_generator, debug_config
debug_config.set_show_steps(False)

# %%
input_path = '/mnt/d/datasets/symmetry_dataset/generation_images_selected_01102022.h5'
generator = symmetry_generator('imagenet', input_path, output_size=(256, 256, 3), rotation=False)
generator.visualize_example(42, 'p4', save_file='../example_images/imagenet_p4_example_steps')
